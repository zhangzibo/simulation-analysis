# %%
from numpy import sqrt, linspace
from numpy.random import uniform

from bokeh.plotting import figure
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="65784bda-8e63-4af9-913c-b1fd2dd9e3db">Loading BokehJS ...</span>
#     </div>

# %%
xs = linspace(0, 1, 100)
ys = sqrt(1 - xs** 2)

SIZE = 10000
pts = uniform(0, 1, size=(SIZE, 2))
inside = pts[:,0] ** 2 + pts[:,1] ** 2 < 1

fig = figure()
fig.line(xs, ys, color='red')
fig.scatter(pts[inside][:,0], pts[inside][:,1], color='blue')
fig.scatter(pts[-inside][:,0], pts[-inside][:,1], color='red')
show(fig)
# Out:
#   <div class="bk-root" id="5af10114-86c9-4edb-a97a-c0acdfe3694e"></div>
