# %%
from numpy import sqrt, linspace
from numpy.random import uniform

from bokeh.plotting import figure
from bokeh.io import show, output_notebook

from IPython.display import Latex, display 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d62dd2d7-d3a4-4521-ab19-e3469e2290a3">Loading BokehJS ...</span>
#     </div>

# %%
xs = linspace(0, 1, 100)
ys = sqrt(1 - xs** 2)

SIZE = 10000
pts = uniform(0, 1, size=(SIZE, 2))
inside = pts[:,0] ** 2 + pts[:,1] ** 2 < 1

pi = sum(inside) / SIZE * 4 
fig = figure()
fig.line(xs, ys, color='red')
fig.scatter(pts[inside][:,0], pts[inside][:,1], color='blue')
fig.scatter(pts[~inside][:,0], pts[~inside][:,1], color='red')
show(fig)
display.latex
# Out:
#   <div class="bk-root" id="d21677b2-d816-4c4b-a820-9415ac4a90e0"></div>
